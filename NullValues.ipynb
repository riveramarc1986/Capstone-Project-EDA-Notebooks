# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import Imputer

# %%
# %pwd
# Out:
# '/Users/marcrivera/Downloads/open-university-learning-analytics-dataset'

# %%
dfstudentinfo = pd.read_csv("studentInfo.csv")
dfstudentasses = pd.read_csv("studentAssessment.csv")
dfvle = pd.read_csv("vle.csv")
dfstudentvle = pd.read_csv("studentVle.csv")
dfstudentreg = pd.read_csv ("studentRegistration.csv")
dfcourses = pd.read_csv ("courses.csv")
dfasses = pd.read_csv ("assessments.csv")

# %%
dfstudentasses.isnull().sum()
# Out:
# id_assessment       0
# id_student          0
# date_submitted      0
# is_banked           0
# score             173
# dtype: int64

# %%
dfvle.isnull().sum()
# Out:
# id_site                 0
# code_module             0
# code_presentation       0
# activity_type           0
# week_from            5243
# week_to              5243
# dtype: int64

# %%
dfstudentvle.isnull().sum()
# Out:
# code_module          0
# code_presentation    0
# id_student           0
# id_site              0
# date                 0
# sum_click            0
# dtype: int64

# %%
dfstudentreg.isnull().sum()
# Out:
# code_module                0
# code_presentation          0
# id_student                 0
# date_registration         45
# date_unregistration    22521
# dtype: int64

# %%
dfasses.isnull().sum()
# Out:
# code_module           0
# code_presentation     0
# id_assessment         0
# assessment_type       0
# date                 11
# weight                0
# dtype: int64

# %%
dfcourses.isnull().sum()
# Out:
# code_module                   0
# code_presentation             0
# module_presentation_length    0
# dtype: int64

# %%
dfstudentinfo.isnull().sum()
# Out:
# code_module                0
# code_presentation          0
# id_student                 0
# gender                     0
# region                     0
# highest_education          0
# imd_band                1111
# age_band                   0
# num_of_prev_attempts       0
# studied_credits            0
# disability                 0
# final_result               0
# dtype: int64

# %%
#finding the rows with null values in imd_band column
dfstudentinfo[dfstudentinfo['imd_band'].isnull()]
# Out:
#       code_module code_presentation  id_student gender                region  \
# 9             AAA             2013J       53025      M          North Region
# 17            AAA             2013J       71361      M               Ireland
# 28            AAA             2013J      104476      M               Ireland
# 34            AAA             2013J      114017      F          North Region
# 65            AAA             2013J      172112      M               Ireland
# 66            AAA             2013J      172797      F               Ireland
# 68            AAA             2013J      175392      M          North Region
# 88            AAA             2013J      227517      M               Ireland
# 180           AAA             2013J      376439      M          North Region
# 184           AAA             2013J      386924      M               Ireland
# 223           AAA             2013J      603861      M          North Region
# ...

# %%
#Dropping the rows with Null Values in 'imd_band' column should we decided to do so
dfstudentinfo.dropna(subset = ['imd_band'],how = 'all').shape
# Out:
# (31482, 12)

# %%
#new data frame df2 with no null values in imd_band column
df2 = dfstudentinfo.dropna(subset = ['imd_band'],how = 'all')

# %%
df2.head()
# Out:
#   code_module code_presentation  id_student gender                region  \
# 0         AAA             2013J       11391      M   East Anglian Region
# 1         AAA             2013J       28400      F              Scotland
# 2         AAA             2013J       30268      F  North Western Region
# 3         AAA             2013J       31604      F     South East Region
# 4         AAA             2013J       32885      F  West Midlands Region
#
#        highest_education imd_band age_band  num_of_prev_attempts  \
# 0       HE Qualification  90-100%     55<=                     0
# 1       HE Qualification   20-30%    35-55                     0
# 2  A Level or Equivalent   30-40%    35-55                     0
# 3  A Level or Equivalent   50-60%    35-55                     0
# 4     Lower Than A Level   50-60%     0-35                     0
#
#    studied_credits disability final_result
# 0              240          N         Pass
# 1               60          N         Pass
# ...

# %%
#checking for null values in d2
df2.isnull().sum()
# Out:
# code_module             0
# code_presentation       0
# id_student              0
# gender                  0
# region                  0
# highest_education       0
# imd_band                0
# age_band                0
# num_of_prev_attempts    0
# studied_credits         0
# disability              0
# final_result            0
# dtype: int64

# %%
df2.shape
# Out:
# (31482, 12)

# %%
#creates and saves new csv to the same folder where the current notebook is running from
df2.to_csv('studentinfo2.csv')

# %%
#cols = dfstudentinfo(imd_band)

# %%
dfstudentinfo.fillna(dfstudentinfo.mode().iloc[0])
# Out:
#       code_module code_presentation  id_student gender                region  \
# 0             AAA             2013J       11391      M   East Anglian Region
# 1             AAA             2013J       28400      F              Scotland
# 2             AAA             2013J       30268      F  North Western Region
# 3             AAA             2013J       31604      F     South East Region
# 4             AAA             2013J       32885      F  West Midlands Region
# 5             AAA             2013J       38053      M                 Wales
# 6             AAA             2013J       45462      M              Scotland
# 7             AAA             2013J       45642      F  North Western Region
# 8             AAA             2013J       52130      F   East Anglian Region
# 9             AAA             2013J       53025      M          North Region
# 10            AAA             2013J       57506      M          South Region
# ...

# %%
dfstudentinfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32593 entries, 0 to 32592
# Data columns (total 12 columns):
# code_module             32593 non-null object
# code_presentation       32593 non-null object
# id_student              32593 non-null int64
# gender                  32593 non-null object
# region                  32593 non-null object
# highest_education       32593 non-null object
# imd_band                31482 non-null object
# age_band                32593 non-null object
# num_of_prev_attempts    32593 non-null int64
# studied_credits         32593 non-null int64
# disability              32593 non-null object
# final_result            32593 non-null object
# dtypes: int64(3), object(9)
# memory usage: 3.0+ MB

# %%
df3 = dfstudentinfo.fillna(dfstudentinfo.mode().iloc[0])

# %%
df3.isnull().sum()
# Out:
# code_module             0
# code_presentation       0
# id_student              0
# gender                  0
# region                  0
# highest_education       0
# imd_band                0
# age_band                0
# num_of_prev_attempts    0
# studied_credits         0
# disability              0
# final_result            0
# dtype: int64
